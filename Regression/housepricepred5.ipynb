# %%
import pandas as pd
from sklearn import linear_model,model_selection,metrics
import math

# %%
house_train=pd.read_csv('C:/Manidhar/MachineLearningLab/datasets/HomePrice/train.csv')

# %%
house_train.info()
house_train.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# RoofMatl         1460 non-null object
# Exterior1st      1460 non-null object
# Exterior2nd      1460 non-null object
# MasVnrType       1452 non-null object
# MasVnrArea       1452 non-null float64
# ExterQual        1460 non-null object
# ExterCond        1460 non-null object
# Foundation       1460 non-null object
# BsmtQual         1423 non-null object
# BsmtCond         1423 non-null object
# BsmtExposure     1422 non-null object
# BsmtFinType1     1423 non-null object
# BsmtFinSF1       1460 non-null int64
# BsmtFinType2     1422 non-null object
# BsmtFinSF2       1460 non-null int64
# BsmtUnfSF        1460 non-null int64
# TotalBsmtSF      1460 non-null int64
# Heating          1460 non-null object
# HeatingQC        1460 non-null object
# CentralAir       1460 non-null object
# Electrical       1459 non-null object
# 1stFlrSF         1460 non-null int64
# 2ndFlrSF         1460 non-null int64
# LowQualFinSF     1460 non-null int64
# GrLivArea        1460 non-null int64
# BsmtFullBath     1460 non-null int64
# BsmtHalfBath     1460 non-null int64
# FullBath         1460 non-null int64
# HalfBath         1460 non-null int64
# BedroomAbvGr     1460 non-null int64
# KitchenAbvGr     1460 non-null int64
# KitchenQual      1460 non-null object
# TotRmsAbvGrd     1460 non-null int64
# Functional       1460 non-null object
# Fireplaces       1460 non-null int64
# FireplaceQu      770 non-null object
# GarageType       1379 non-null object
# GarageYrBlt      1379 non-null float64
# GarageFinish     1379 non-null object
# GarageCars       1460 non-null int64
# GarageArea       1460 non-null int64
# GarageQual       1379 non-null object
# GarageCond       1379 non-null object
# PavedDrive       1460 non-null object
# WoodDeckSF       1460 non-null int64
# OpenPorchSF      1460 non-null int64
# EnclosedPorch    1460 non-null int64
# 3SsnPorch        1460 non-null int64
# ScreenPorch      1460 non-null int64
# PoolArea         1460 non-null int64
# PoolQC           7 non-null object
# Fence            281 non-null object
# MiscFeature      54 non-null object
# MiscVal          1460 non-null int64
# MoSold           1460 non-null int64
# YrSold           1460 non-null int64
# SaleType         1460 non-null object
# SaleCondition    1460 non-null object
# SalePrice        1460 non-null int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB
# (1460, 81)

# %%
house_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000
#
#            ...         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count      ...        1460.000000  1460.000000    1460.000000  1460.000000
# mean       ...          94.244521    46.660274      21.954110     3.409589
# std        ...         125.338794    66.256028      61.119149    29.317331
# min        ...           0.000000     0.000000       0.000000     0.000000
# 25%        ...           0.000000     0.000000       0.000000     0.000000
# 50%        ...           0.000000    25.000000       0.000000     0.000000
# 75%        ...         168.000000    68.000000       0.000000     0.000000
# max        ...         857.000000   547.000000     552.000000   508.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold  \
# count  1460.000000  1460.000000   1460.000000  1460.000000  1460.000000
# mean     15.060959     2.758904     43.489041     6.321918  2007.815753
# std      55.757415    40.177307    496.123024     2.703626     1.328095
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     5.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     480.000000   738.000000  15500.000000    12.000000  2010.000000
#
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000
#
# [8 rows x 38 columns]

# %%
house_train.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
#                   ...
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# FireplaceQu       object
# GarageType        object
# GarageYrBlt      float64
# GarageFinish      object
# GarageCars         int64
# GarageArea         int64
# GarageQual        object
# GarageCond        object
# PavedDrive        object
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# PoolQC            object
# Fence             object
# MiscFeature       object
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %% [markdown]
# #house_train['MSSubClass']=house_train['MSSubClass'].astype('category') not sure why it is not working. need to look into it laterm

# %%
house_train['BedroomAbvGr'].dtype
print(house_train.select_dtypes(exclude='number')).columns
print(house_train.select_dtypes(include='number')).columns
# Out:
#      MSZoning Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   NaN      IR1         Lvl    AllPub       FR2       Gtl
# 5          RL   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 6          RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 7          RL   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 8          RM   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 9          RL   NaN      Reg         Lvl    AllPub    Corner       Gtl
# 10         RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 11         RL   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 12         RL   NaN      IR2         Lvl    AllPub    Inside       Gtl
# 13         RL   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 14         RL   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 15         RM   NaN      Reg         Lvl    AllPub    Corner       Gtl
# 16         RL   NaN      IR1         Lvl    AllPub   CulDSac       Gtl
# 17         RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 18         RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 19         RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 20         RL   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 21         RM  Grvl      Reg         Bnk    AllPub    Inside       Gtl
# 22         RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 23         RM   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 24         RL   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 25         RL   NaN      Reg         Lvl    AllPub    Corner       Gtl
# 26         RL   NaN      Reg         Lvl    AllPub    Corner       Gtl
# 27         RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 28         RL   NaN      IR1         Lvl    AllPub   CulDSac       Gtl
# 29         RM   NaN      IR1         Lvl    AllPub    Inside       Gtl
# ...       ...   ...      ...         ...       ...       ...       ...
# 1430       RL   NaN      IR3         Lvl    AllPub    Inside       Gtl
# 1431       RL   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 1432       RL  Grvl      Reg         Lvl    AllPub    Inside       Gtl
# 1433       RL   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 1434       RL   NaN      Reg         Low    AllPub    Inside       Mod
# 1435       RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1436       RL   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 1437       RL   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 1438       RM   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1439       RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1440       RL   NaN      IR1         Bnk    AllPub    Inside       Mod
# 1441       RM   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1442       FV   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1443       RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1444       RL   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 1445       RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1446       RL   NaN      IR1         Lvl    AllPub   CulDSac       Gtl
# 1447       RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1448       RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1449       RM   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1450       RL   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 1451       RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1452       RM   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1453       RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1454       FV  Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1455       RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2      ...      Electrical Functional  \
# 0         CollgCr       Norm       Norm      ...           SBrkr        Typ
# 1         Veenker      Feedr       Norm      ...           SBrkr        Typ
# 2         CollgCr       Norm       Norm      ...           SBrkr        Typ
# 3         Crawfor       Norm       Norm      ...           SBrkr        Typ
# 4         NoRidge       Norm       Norm      ...           SBrkr        Typ
# 5         Mitchel       Norm       Norm      ...           SBrkr        Typ
# 6         Somerst       Norm       Norm      ...           SBrkr        Typ
# 7          NWAmes       PosN       Norm      ...           SBrkr        Typ
# 8         OldTown     Artery       Norm      ...           FuseF       Min1
# 9         BrkSide     Artery     Artery      ...           SBrkr        Typ
# 10         Sawyer       Norm       Norm      ...           SBrkr        Typ
# 11        NridgHt       Norm       Norm      ...           SBrkr        Typ
# 12         Sawyer       Norm       Norm      ...           SBrkr        Typ
# 13        CollgCr       Norm       Norm      ...           SBrkr        Typ
# 14          NAmes       Norm       Norm      ...           SBrkr        Typ
# 15        BrkSide       Norm       Norm      ...           FuseA        Typ
# 16          NAmes       Norm       Norm      ...           SBrkr        Typ
# 17         Sawyer       Norm       Norm      ...           SBrkr        Typ
# 18        SawyerW       RRAe       Norm      ...           SBrkr        Typ
# 19          NAmes       Norm       Norm      ...           SBrkr       Min1
# 20        NridgHt       Norm       Norm      ...           SBrkr        Typ
# 21         IDOTRR       Norm       Norm      ...           FuseF        Typ
# 22        CollgCr       Norm       Norm      ...           SBrkr        Typ
# 23        MeadowV       Norm       Norm      ...           SBrkr        Typ
# 24         Sawyer       Norm       Norm      ...           SBrkr        Typ
# 25        NridgHt       Norm       Norm      ...           SBrkr        Typ
# 26          NAmes       Norm       Norm      ...           SBrkr        Typ
# 27        NridgHt       Norm       Norm      ...           SBrkr        Typ
# 28          NAmes       Norm       Norm      ...           SBrkr        Typ
# 29        BrkSide      Feedr       RRNn      ...           SBrkr        Typ
# ...           ...        ...        ...      ...             ...        ...
# 1430      Gilbert       RRAn       Norm      ...           SBrkr        Typ
# 1431      NPkVill       Norm       Norm      ...           SBrkr        Typ
# 1432      OldTown       Norm       Norm      ...           SBrkr        Typ
# 1433      Gilbert       Norm       Norm      ...           SBrkr        Typ
# 1434      Mitchel       Norm       Norm      ...           SBrkr        Typ
# 1435        NAmes       Norm       Norm      ...           SBrkr        Typ
# 1436        NAmes       Norm       Norm      ...           SBrkr        Typ
# 1437      NridgHt       Norm       Norm      ...           SBrkr        Typ
# 1438      OldTown     Artery       Norm      ...           FuseA        Typ
# 1439       NWAmes       Norm       Norm      ...           SBrkr        Typ
# 1440      Crawfor       Norm       Norm      ...           SBrkr       Min1
# 1441      CollgCr       Norm       Norm      ...           SBrkr        Typ
# 1442      Somerst       Norm       Norm      ...           SBrkr        Typ
# 1443      BrkSide       Norm       Norm      ...           FuseF        Typ
# 1444      CollgCr       Norm       Norm      ...           SBrkr        Typ
# 1445       Sawyer       Norm       Norm      ...           SBrkr        Typ
# 1446      Mitchel       Norm       Norm      ...           SBrkr        Typ
# 1447      CollgCr       Norm       Norm      ...           SBrkr        Typ
# 1448      Edwards       Norm       Norm      ...           SBrkr       Min2
# 1449      MeadowV       Norm       Norm      ...           SBrkr        Typ
# 1450        NAmes       Norm       Norm      ...           SBrkr        Typ
# 1451      Somerst       Norm       Norm      ...           SBrkr        Typ
# 1452      Edwards       Norm       Norm      ...           SBrkr        Typ
# 1453      Mitchel       Norm       Norm      ...           SBrkr        Typ
# 1454      Somerst       Norm       Norm      ...           SBrkr        Typ
# 1455      Gilbert       Norm       Norm      ...           SBrkr        Typ
# 1456       NWAmes       Norm       Norm      ...           SBrkr       Min1
# 1457      Crawfor       Norm       Norm      ...           SBrkr        Typ
# 1458        NAmes       Norm       Norm      ...           FuseA        Typ
# 1459      Edwards       Norm       Norm      ...           SBrkr        Typ
#
#      GarageType GarageFinish PavedDrive PoolQC  Fence MiscFeature SaleType  \
# 0        Attchd          RFn          Y    NaN    NaN         NaN       WD
# 1        Attchd          RFn          Y    NaN    NaN         NaN       WD
# 2        Attchd          RFn          Y    NaN    NaN         NaN       WD
# 3        Detchd          Unf          Y    NaN    NaN         NaN       WD
# 4        Attchd          RFn          Y    NaN    NaN         NaN       WD
# 5        Attchd          Unf          Y    NaN  MnPrv        Shed       WD
# 6        Attchd          RFn          Y    NaN    NaN         NaN       WD
# 7        Attchd          RFn          Y    NaN    NaN        Shed       WD
# 8        Detchd          Unf          Y    NaN    NaN         NaN       WD
# 9        Attchd          RFn          Y    NaN    NaN         NaN       WD
# 10       Detchd          Unf          Y    NaN    NaN         NaN       WD
# 11      BuiltIn          Fin          Y    NaN    NaN         NaN      New
# 12       Detchd          Unf          Y    NaN    NaN         NaN       WD
# 13       Attchd          RFn          Y    NaN    NaN         NaN      New
# 14       Attchd          RFn          Y    NaN   GdWo         NaN       WD
# 15       Detchd          Unf          Y    NaN  GdPrv         NaN       WD
# 16       Attchd          Fin          Y    NaN    NaN        Shed       WD
# 17      CarPort          Unf          Y    NaN    NaN        Shed       WD
# 18       Detchd          Unf          Y    NaN    NaN         NaN       WD
# 19       Attchd          Unf          Y    NaN  MnPrv         NaN      COD
# 20      BuiltIn          RFn          Y    NaN    NaN         NaN      New
# 21       Attchd          Unf          N    NaN  GdPrv         NaN       WD
# 22       Attchd          RFn          Y    NaN    NaN         NaN       WD
# 23       Attchd          Unf          Y    NaN    NaN         NaN       WD
# 24       Attchd          Unf          Y    NaN  MnPrv         NaN       WD
# 25       Attchd          RFn          Y    NaN    NaN         NaN       WD
# 26       Detchd          Unf          Y    NaN    NaN         NaN       WD
# 27       Attchd          RFn          Y    NaN    NaN         NaN       WD
# 28       Attchd          RFn          Y    NaN    NaN         NaN       WD
# 29       Detchd          Unf          Y    NaN    NaN         NaN       WD
# ...         ...          ...        ...    ...    ...         ...      ...
# 1430    BuiltIn          Fin          Y    NaN    NaN         NaN       WD
# 1431     Attchd          RFn          Y    NaN    NaN         NaN       WD
# 1432     Detchd          Unf          Y    NaN    NaN         NaN       WD
# 1433     Attchd          Fin          Y    NaN    NaN         NaN       WD
# 1434     Attchd          RFn          P    NaN    NaN         NaN       WD
# 1435     Attchd          RFn          Y    NaN  GdPrv         NaN      COD
# 1436     Detchd          Unf          Y    NaN   GdWo         NaN       WD
# 1437     Attchd          Fin          Y    NaN    NaN         NaN      New
# 1438     Attchd          Unf          Y    NaN  MnPrv         NaN       WD
# 1439     Attchd          RFn          Y    NaN    NaN         NaN       WD
# 1440     Detchd          Fin          Y    NaN    NaN         NaN       WD
# 1441     Attchd          RFn          Y    NaN    NaN         NaN       WD
# 1442     Attchd          Fin          Y    NaN    NaN         NaN       WD
# 1443     Detchd          Unf          P    NaN    NaN         NaN       WD
# 1444     Attchd          RFn          Y    NaN    NaN         NaN       WD
# 1445     Detchd          Unf          Y    NaN    NaN         NaN       WD
# 1446     Attchd          Unf          P    NaN    NaN         NaN       WD
# 1447     Attchd          RFn          Y    NaN    NaN         NaN       WD
# 1448     Detchd          Unf          Y    NaN   GdWo         NaN       WD
# 1449        NaN          NaN          Y    NaN    NaN         NaN       WD
# 1450        NaN          NaN          Y    NaN    NaN         NaN       WD
# 1451     Attchd          Fin          Y    NaN    NaN         NaN      New
# 1452    Basment          Fin          Y    NaN    NaN         NaN       WD
# 1453        NaN          NaN          Y    NaN    NaN         NaN       WD
# 1454     Attchd          RFn          Y    NaN    NaN         NaN       WD
# 1455     Attchd          RFn          Y    NaN    NaN         NaN       WD
# 1456     Attchd          Unf          Y    NaN  MnPrv         NaN       WD
# 1457     Attchd          RFn          Y    NaN  GdPrv        Shed       WD
# 1458     Attchd          Unf          Y    NaN    NaN         NaN       WD
# 1459     Attchd          Fin          Y    NaN    NaN         NaN       WD
#
#      SaleCondition
# 0           Normal
# 1           Normal
# 2           Normal
# 3          Abnorml
# 4           Normal
# 5           Normal
# 6           Normal
# 7           Normal
# 8          Abnorml
# 9           Normal
# 10          Normal
# 11         Partial
# 12          Normal
# 13         Partial
# 14          Normal
# 15          Normal
# 16          Normal
# 17          Normal
# 18          Normal
# 19         Abnorml
# 20         Partial
# 21          Normal
# 22          Normal
# 23          Normal
# 24          Normal
# 25          Normal
# 26          Normal
# 27          Normal
# 28          Normal
# 29          Normal
# ...            ...
# 1430        Normal
# 1431        Normal
# 1432        Normal
# 1433        Normal
# 1434        Normal
# 1435       Abnorml
# 1436        Normal
# 1437       Partial
# 1438        Normal
# 1439        Normal
# 1440        Normal
# 1441        Normal
# 1442        Normal
# 1443        Normal
# 1444        Normal
# 1445        Normal
# 1446        Normal
# 1447        Normal
# 1448        Normal
# 1449       Abnorml
# 1450        Normal
# 1451       Partial
# 1452        Normal
# 1453       Abnorml
# 1454        Normal
# 1455        Normal
# 1456        Normal
# 1457        Normal
# 1458        Normal
# 1459        Normal
#
# [1460 rows x 33 columns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-abcece5cb53f> in <module>()
#       1 house_train['BedroomAbvGr'].dtype
# ----> 2 print(house_train.select_dtypes(exclude='number')).columns
#       3 print(house_train.select_dtypes(include='number')).columns
#
# AttributeError: 'NoneType' object has no attribute 'columns'

# %%
# 3. Preprocessing [Filling the missing data (Imputation), converting categoric to continious using onehot encodeing, Data normalization or standardization, Data Transformation]
# MSSubclass, Street need to convert this into onehot as it is categoric

cat_to_continues=['MSSubClass','Street']
house_train=pd.get_dummies(house_train,columns=cat_to_continues)
house_train.info()
house_train.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 96 columns):
# Id                1460 non-null int64
# MSZoning          1460 non-null object
# LotFrontage       1201 non-null float64
# LotArea           1460 non-null int64
# Alley             91 non-null object
# LotShape          1460 non-null object
# LandContour       1460 non-null object
# Utilities         1460 non-null object
# LotConfig         1460 non-null object
# LandSlope         1460 non-null object
# Neighborhood      1460 non-null object
# Condition1        1460 non-null object
# Condition2        1460 non-null object
# BldgType          1460 non-null object
# HouseStyle        1460 non-null object
# OverallQual       1460 non-null int64
# OverallCond       1460 non-null int64
# YearBuilt         1460 non-null int64
# YearRemodAdd      1460 non-null int64
# RoofStyle         1460 non-null object
# RoofMatl          1460 non-null object
# Exterior1st       1460 non-null object
# Exterior2nd       1460 non-null object
# MasVnrType        1452 non-null object
# MasVnrArea        1452 non-null float64
# ExterQual         1460 non-null object
# ExterCond         1460 non-null object
# Foundation        1460 non-null object
# BsmtQual          1423 non-null object
# BsmtCond          1423 non-null object
# BsmtExposure      1422 non-null object
# BsmtFinType1      1423 non-null object
# BsmtFinSF1        1460 non-null int64
# BsmtFinType2      1422 non-null object
# BsmtFinSF2        1460 non-null int64
# BsmtUnfSF         1460 non-null int64
# TotalBsmtSF       1460 non-null int64
# Heating           1460 non-null object
# HeatingQC         1460 non-null object
# CentralAir        1460 non-null object
# Electrical        1459 non-null object
# 1stFlrSF          1460 non-null int64
# 2ndFlrSF          1460 non-null int64
# LowQualFinSF      1460 non-null int64
# GrLivArea         1460 non-null int64
# BsmtFullBath      1460 non-null int64
# BsmtHalfBath      1460 non-null int64
# FullBath          1460 non-null int64
# HalfBath          1460 non-null int64
# BedroomAbvGr      1460 non-null int64
# KitchenAbvGr      1460 non-null int64
# KitchenQual       1460 non-null object
# TotRmsAbvGrd      1460 non-null int64
# Functional        1460 non-null object
# Fireplaces        1460 non-null int64
# FireplaceQu       770 non-null object
# GarageType        1379 non-null object
# GarageYrBlt       1379 non-null float64
# GarageFinish      1379 non-null object
# GarageCars        1460 non-null int64
# GarageArea        1460 non-null int64
# GarageQual        1379 non-null object
# GarageCond        1379 non-null object
# PavedDrive        1460 non-null object
# WoodDeckSF        1460 non-null int64
# OpenPorchSF       1460 non-null int64
# EnclosedPorch     1460 non-null int64
# 3SsnPorch         1460 non-null int64
# ScreenPorch       1460 non-null int64
# PoolArea          1460 non-null int64
# PoolQC            7 non-null object
# Fence             281 non-null object
# MiscFeature       54 non-null object
# MiscVal           1460 non-null int64
# MoSold            1460 non-null int64
# YrSold            1460 non-null int64
# SaleType          1460 non-null object
# SaleCondition     1460 non-null object
# SalePrice         1460 non-null int64
# MSSubClass_20     1460 non-null uint8
# MSSubClass_30     1460 non-null uint8
# MSSubClass_40     1460 non-null uint8
# MSSubClass_45     1460 non-null uint8
# MSSubClass_50     1460 non-null uint8
# MSSubClass_60     1460 non-null uint8
# MSSubClass_70     1460 non-null uint8
# MSSubClass_75     1460 non-null uint8
# MSSubClass_80     1460 non-null uint8
# MSSubClass_85     1460 non-null uint8
# MSSubClass_90     1460 non-null uint8
# MSSubClass_120    1460 non-null uint8
# MSSubClass_160    1460 non-null uint8
# MSSubClass_180    1460 non-null uint8
# MSSubClass_190    1460 non-null uint8
# Street_Grvl       1460 non-null uint8
# Street_Pave       1460 non-null uint8
# dtypes: float64(3), int64(34), object(42), uint8(17)
# memory usage: 925.4+ KB
# Index(['Id', 'MSZoning', 'LotFrontage', 'LotArea', 'Alley', 'LotShape',
#        'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood',
#        'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
#        '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces',
#        'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
#        'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice',
#        'MSSubClass_20', 'MSSubClass_30', 'MSSubClass_40', 'MSSubClass_45',
#        'MSSubClass_50', 'MSSubClass_60', 'MSSubClass_70', 'MSSubClass_75',
#        'MSSubClass_80', 'MSSubClass_85', 'MSSubClass_90', 'MSSubClass_120',
#        'MSSubClass_160', 'MSSubClass_180', 'MSSubClass_190', 'Street_Grvl',
#        'Street_Pave'],
#       dtype='object')

# %%
# Functional style of programming
# These are called Ordinal Features with relation
mappings={'Po' :1,'Fa':2,'TA':3,'Gd':4,'Ex':5}
features1 =['ExterQual','ExterCond','BsmtCond','BsmtQual','KitchenQual','HeatingQC','GarageQual','GarageCond','FireplaceQu']
for f1 in features1:
    house_train[f1]=house_train[f1].map(mappings)
    house_train.loc[house_train[f1].isnull() == True,f1]=0

# 4. Feature Engineering [Feature selection based on feature importance, Filtering features,Create new features if required, transforming of features]
dims=['LotArea','OverallQual','OverallCond','MSSubClass_20', 'MSSubClass_30', 'MSSubClass_40', 'MSSubClass_45',
       'MSSubClass_50', 'MSSubClass_60', 'MSSubClass_70', 'MSSubClass_75',
       'MSSubClass_80', 'MSSubClass_85', 'MSSubClass_90', 'MSSubClass_120',
       'MSSubClass_160', 'MSSubClass_180', 'MSSubClass_190', 'Street_Grvl',
       'Street_Pave']

dims.extend(features1)

# %%
X_train=house_train[dims]
X_train.info()
y_train=house_train['SalePrice']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 29 columns):
# LotArea           1460 non-null int64
# OverallQual       1460 non-null int64
# OverallCond       1460 non-null int64
# MSSubClass_20     1460 non-null uint8
# MSSubClass_30     1460 non-null uint8
# MSSubClass_40     1460 non-null uint8
# MSSubClass_45     1460 non-null uint8
# MSSubClass_50     1460 non-null uint8
# MSSubClass_60     1460 non-null uint8
# MSSubClass_70     1460 non-null uint8
# MSSubClass_75     1460 non-null uint8
# MSSubClass_80     1460 non-null uint8
# MSSubClass_85     1460 non-null uint8
# MSSubClass_90     1460 non-null uint8
# MSSubClass_120    1460 non-null uint8
# MSSubClass_160    1460 non-null uint8
# MSSubClass_180    1460 non-null uint8
# MSSubClass_190    1460 non-null uint8
# Street_Grvl       1460 non-null uint8
# Street_Pave       1460 non-null uint8
# ExterQual         1460 non-null int64
# ExterCond         1460 non-null int64
# BsmtCond          1460 non-null float64
# BsmtQual          1460 non-null float64
# KitchenQual       1460 non-null int64
# HeatingQC         1460 non-null int64
# GarageQual        1460 non-null float64
# GarageCond        1460 non-null float64
# FireplaceQu       1460 non-null float64
# dtypes: float64(5), int64(7), uint8(17)
# memory usage: 161.2 KB

# %%
# 5. Model Building
mylr=linear_model.LinearRegression()
mylr.fit(X_train,y_train)
print(mylr.coef_)
print(mylr.intercept_)
# Out:
# [ 1.07625503e+00  2.34344058e+04  2.54172474e+03  1.26654628e+04
#  -3.10563197e+03 -9.48542261e+03 -2.36824411e+04  5.70270273e+03
#   1.89314419e+04  4.44899169e+03  7.48912794e+03  4.84135822e+03
#  -6.26465622e+01  2.75442813e+04 -2.08827282e+04 -2.19876585e+04
#  -1.21961610e+04  9.77932335e+03 -1.13495364e+04  1.13495364e+04
#   1.83626334e+04  5.94632980e+02 -1.20404264e+04  1.73786434e+04
#   1.67147341e+04  5.96193507e+02  8.17017087e+03 -6.71431988e+03
#   5.89590398e+03]
# -172360.3698124394

# %%
mylr.score(X_train,y_train)
y_predict=mylr.predict(X_train)
metrics.explained_variance_score(y_train,y_predict) # this is called train score
meansqr=metrics.mean_squared_error(y_train,y_predict) # this is called train error
print('Root mean square Error : ',math.sqrt(meansqr))

# Resampling score or CV score
print('CV Score : ',model_selection.cross_val_score(mylr,X_train,y_train,cv=10).mean())
# Out:
# Root mean square Error :  40085.72714964752
# CV Score :  0.7394747045798683
