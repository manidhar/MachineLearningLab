# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf

# %%
py.offline.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
df=pd.read_csv('F:\\DataSciencePractise\\MachineLearningLab\\datasets\\weight-height.csv')

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df.dtypes
# Out:
# Gender     object
# Height    float64
# Weight    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  10000 non-null  object
#  1   Height  10000 non-null  float64
#  2   Weight  10000 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 234.5+ KB

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df_male=df[df['Gender']=='Male']
df_female=df[df['Gender']=='Female']

# %%
df_male.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  5000 non-null   object
#  1   Height  5000 non-null   float64
#  2   Weight  5000 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 156.2+ KB

# %%
df_female.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 5000 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  5000 non-null   object
#  1   Height  5000 non-null   float64
#  2   Weight  5000 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 156.2+ KB

# %%
# Univariate,BiVariate,Multi Variate Analysis

# %%
sns.histplot(df_male['Height'],kde=True)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Count'>

# %%
sns.histplot(df_female['Height'],kde=True)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Count'>

# %%
sns.boxplot(df_male['Height'],orient='Horizantal')
# Out:
# C:\Users\manid\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='Height'>

# %%
plt.plot(df_male['Height'],np.zeros_like(df_male['Height']),'bo')
plt.plot(df_female['Height'],np.zeros_like(df_female['Height']),'ro')
plt.show()

# %%
sns.FacetGrid(df,hue='Gender',size=8).map(sns.distplot,"Height").add_legend()
# Out:
# C:\Users\manid\Anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning:
#
# The `size` parameter has been renamed to `height`; please update your code.
#
# C:\Users\manid\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\manid\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
sns.FacetGrid(df,hue='Gender',size=8).map(sns.distplot,"Weight").add_legend()
# Out:
# C:\Users\manid\Anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning:
#
# The `size` parameter has been renamed to `height`; please update your code.
#
# C:\Users\manid\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\manid\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
# percentails
print("25 percentail value is ",np.percentile(df_male['Weight'],25))
print("50 percentail value is ",np.percentile(df_male['Weight'],50))
print("75 percentail value is ",np.percentile(df_male['Weight'],75))
print("90 percentail value is ",np.percentile(df_male['Weight'],90))
# Out:
# 25 percentail value is  173.887767334218
# 50 percentail value is  187.033546088862
# 75 percentail value is  200.35780180200078
# 90 percentail value is  211.76868488615952
